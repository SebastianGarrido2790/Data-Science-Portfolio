# %% [markdown]
# ## **Understanding the Business Context**
#
# Before diving into the data, it’s important to recall the business objectives:
#
# - **Customer Segmentation:** Identify distinct groups of customers based on their buying behaviors.
# - **RFM Analysis:** Use Recency (how recently a customer made a purchase), Frequency (how often they purchase), and Monetary (how much they spend) to gauge customer value.
# - **Actionable Insights:** Generate recommendations for personalized marketing and improved customer service.
#
# The analysis helps answer key business questions such as identifying the most valuable or loyal customers, understanding purchase behavior patterns, and determining the impact of promotions.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plot_settings import set_plot_settings

set_plot_settings()

# Ensure floating-point numbers are displayed with two decimal places and a width of 20 characters for alignment
pd.options.display.float_format = lambda x: f"{x:20.2f}"
# Show all columns on output
pd.set_option("display.max_columns", 999)

# %%
df = pd.read_csv("../../data/interim/online_retail_2009_2010.csv")

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                 InvoiceDate                Price          Customer ID  \
# 0       2009-12-01 07:45:00                 6.95             13085.00
# 1       2009-12-01 07:45:00                 6.75             13085.00
# 2       2009-12-01 07:45:00                 6.75             13085.00
# 3       2009-12-01 07:45:00                 2.10             13085.00
# 4       2009-12-01 07:45:00                 1.25             13085.00
# ...                     ...                  ...                  ...
# 525456  2010-12-09 20:01:00                 2.95             17530.00
# 525457  2010-12-09 20:01:00                 3.75             17530.00
# 525458  2010-12-09 20:01:00                 3.75             17530.00
# 525459  2010-12-09 20:01:00                 3.75             17530.00
# 525460  2010-12-09 20:01:00                 1.95             17530.00
#
#                Country
# 0       United Kingdom
# 1       United Kingdom
# 2       United Kingdom
# 3       United Kingdom
# 4       United Kingdom
# ...                ...
# 525456  United Kingdom
# 525457  United Kingdom
# 525458  United Kingdom
# 525459  United Kingdom
# 525460  United Kingdom
#
# [525461 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  object
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 32.1+ MB

# %% [markdown]
# **Customer ID:** About 107,927 entries are missing in Customer ID. Since customer segmentation relies on identifying individual customers (for RFM analysis), we may need to filter these out or handle them appropriately.

# %%
df.describe()
# Out:
#                   Quantity                Price          Customer ID
# count            525461.00            525461.00            417534.00
# mean                 10.34                 4.69             15360.65
# std                 107.42               146.13              1680.81
# min               -9600.00            -53594.36             12346.00
# 25%                   1.00                 1.25             13983.00
# 50%                   3.00                 2.10             15311.00
# 75%                  10.00                 4.21             16799.00
# max               19152.00             25111.09             18287.00

# %% [markdown]
# **Statistical Summaries**
#
# - **Quantity:**
#   - **Range:** From -9600 to 19152. The presence of negative quantities likely indicates returns or cancellations.
#   - **Central Tendency:** The median is 3, suggesting that most transactions involve a small number of items.
#   - **Variation:** A high standard deviation (107.42) indicates significant variability, which might be worth exploring further (e.g., separating orders and returns).
#
# - **Price:**
#   - **Range:** From -53594.36 to 25111.09. Negative prices could be due to errors or adjustments (like refunds or cancellations), and extreme values might be outliers.
#   - **Central Tendency:** The median price is 2.10, with a mean of 4.69, hinting at a right-skewed distribution where a few expensive items increase the average.
#
# - **Customer ID:**
#   - **Range and Central Tendency:** The median is 15,311, and the mean is 15,360.65, but since this is an identifier, the actual numeric values are less important than their uniqueness and distribution.
#
# - **InvoiceDate:**
#   - **Range:** The dates span from 2009-12-01 to 2010-12-09, providing a full year of transactional data. This temporal span is perfect for calculating recency and understanding seasonal patterns.

# %%
df.describe(include="O")
# Out:
#        Invoice StockCode                         Description  \
# count   525461    525461                              522533
# unique   28816      4632                                4681
# top     537434    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq       675      3516                                3549
#
#                 InvoiceDate         Country
# count                525461          525461
# unique                25296              40
# top     2010-12-06 16:57:00  United Kingdom
# freq                    675          485852

# %% [markdown]
# **Country:** Only 40 unique values, with the majority being "United Kingdom" (as indicated by the top frequency). This suggests a strong geographical focus which could be significant in customer segmentation.

# %% [markdown]
# ### **Customer ID**

# %%
df[df["Customer ID"].isna()].head(10)
# Out:
#      Invoice StockCode                   Description  Quantity  \
# 263   489464     21733                  85123a mixed       -96
# 283   489463     71477                         short      -240
# 284   489467    85123A                   21733 mixed      -192
# 470   489521     21646                           NaN       -50
# 577   489525    85226C     BLUE PULL BACK RACING CAR         1
# 578   489525     85227   SET/6 3D KIT CARDS FOR KIDS         1
# 1055  489548     22271          FELTCRAFT DOLL ROSIE         1
# 1056  489548     22254          FELT TOADSTOOL LARGE        12
# 1057  489548     22273          FELTCRAFT DOLL MOLLY         3
# 1058  489548     22195  LARGE HEART MEASURING SPOONS         1
#
#               InvoiceDate                Price  Customer ID         Country
# 263   2009-12-01 10:52:00                 0.00          NaN  United Kingdom
# 283   2009-12-01 10:52:00                 0.00          NaN  United Kingdom
# 284   2009-12-01 10:53:00                 0.00          NaN  United Kingdom
# 470   2009-12-01 11:44:00                 0.00          NaN  United Kingdom
# 577   2009-12-01 11:49:00                 0.55          NaN  United Kingdom
# 578   2009-12-01 11:49:00                 0.85          NaN  United Kingdom
# 1055  2009-12-01 12:32:00                 2.95          NaN  United Kingdom
# 1056  2009-12-01 12:32:00                 1.25          NaN  United Kingdom
# 1057  2009-12-01 12:32:00                 2.95          NaN  United Kingdom
# 1058  2009-12-01 12:32:00                 1.65          NaN  United Kingdom

# %% [markdown]
# - Probably drop null customer, unknow customer does not allow us to make customer segmentation.

# %% [markdown]
# ### **Quantity**

# %%
df[df["Quantity"] < 0].head(10)
# Out:
#      Invoice StockCode                        Description  Quantity  \
# 178  C489449     22087           PAPER BUNTING WHITE LACE       -12
# 179  C489449    85206A       CREAM FELT EASTER EGG BASKET        -6
# 180  C489449     21895      POTTING SHED SOW 'N' GROW SET        -4
# 181  C489449     21896                 POTTING SHED TWINE        -6
# 182  C489449     22083         PAPER CHAIN KIT RETRO SPOT       -12
# 183  C489449     21871                SAVE THE PLANET MUG       -12
# 184  C489449     84946    ANTIQUE SILVER TEA GLASS ETCHED       -12
# 185  C489449    84970S  HANGING HEART ZINC T-LIGHT HOLDER       -24
# 186  C489449     22090          PAPER BUNTING RETRO SPOTS       -12
# 196  C489459    90200A         PURPLE SWEETHEART BRACELET        -3
#
#              InvoiceDate                Price          Customer ID  \
# 178  2009-12-01 10:33:00                 2.95             16321.00
# 179  2009-12-01 10:33:00                 1.65             16321.00
# 180  2009-12-01 10:33:00                 4.25             16321.00
# 181  2009-12-01 10:33:00                 2.10             16321.00
# 182  2009-12-01 10:33:00                 2.95             16321.00
# 183  2009-12-01 10:33:00                 1.25             16321.00
# 184  2009-12-01 10:33:00                 1.25             16321.00
# 185  2009-12-01 10:33:00                 0.85             16321.00
# 186  2009-12-01 10:33:00                 2.95             16321.00
# 196  2009-12-01 10:44:00                 4.25             17592.00
#
#             Country
# 178       Australia
# 179       Australia
# 180       Australia
# 181       Australia
# 182       Australia
# 183       Australia
# 184       Australia
# 185       Australia
# 186       Australia
# 196  United Kingdom

# %% [markdown]
# ### **Invoice**

# %%
df["Invoice"] = df["Invoice"].astype("str")
# Six digits number only
df[df["Invoice"].str.match("^\\d{6}$") == False]
# Out:
#         Invoice StockCode                       Description  Quantity  \
# 178     C489449     22087          PAPER BUNTING WHITE LACE       -12
# 179     C489449    85206A      CREAM FELT EASTER EGG BASKET        -6
# 180     C489449     21895     POTTING SHED SOW 'N' GROW SET        -4
# 181     C489449     21896                POTTING SHED TWINE        -6
# 182     C489449     22083        PAPER CHAIN KIT RETRO SPOT       -12
# ...         ...       ...                               ...       ...
# 524695  C538123     22956          36 FOIL HEART CAKE CASES        -2
# 524696  C538124         M                            Manual        -4
# 524697  C538124     22699  ROSES REGENCY TEACUP AND SAUCER         -1
# 524698  C538124     22423          REGENCY CAKESTAND 3 TIER        -1
# 525282  C538164    35004B       SET OF 3 BLACK FLYING DUCKS        -1
#
#                 InvoiceDate                Price          Customer ID  \
# 178     2009-12-01 10:33:00                 2.95             16321.00
# 179     2009-12-01 10:33:00                 1.65             16321.00
# 180     2009-12-01 10:33:00                 4.25             16321.00
# 181     2009-12-01 10:33:00                 2.10             16321.00
# 182     2009-12-01 10:33:00                 2.95             16321.00
# ...                     ...                  ...                  ...
# 524695  2010-12-09 15:41:00                 2.10             12605.00
# 524696  2010-12-09 15:43:00                 0.50             15329.00
# 524697  2010-12-09 15:43:00                 2.95             15329.00
# 524698  2010-12-09 15:43:00                12.75             15329.00
# 525282  2010-12-09 17:32:00                 1.95             14031.00
#
#                Country
# 178          Australia
# 179          Australia
# 180          Australia
# 181          Australia
# 182          Australia
# ...                ...
# 524695         Germany
# 524696  United Kingdom
# 524697  United Kingdom
# 524698  United Kingdom
# 525282  United Kingdom
#
# [10209 rows x 8 columns]

# %% [markdown]
# **Is "C" the only character in Invoice?**

# %%
# Take only characters
df["Invoice"].str.replace("[0-9]", "", regex=True).unique()
# Out:
# array(['', 'C', 'A'], dtype=object)

# %%
df[df["Invoice"].str.startswith("A")]
# Out:
#         Invoice StockCode      Description  Quantity          InvoiceDate  \
# 179403  A506401         B  Adjust bad debt         1  2010-04-29 13:36:00
# 276274  A516228         B  Adjust bad debt         1  2010-07-19 11:24:00
# 403472  A528059         B  Adjust bad debt         1  2010-10-20 12:04:00
#
#                       Price  Customer ID         Country
# 179403            -53594.36          NaN  United Kingdom
# 276274            -44031.79          NaN  United Kingdom
# 403472            -38925.87          NaN  United Kingdom

# %% [markdown]
# - This seems to be accounting transactions.

# %% [markdown]
# ### **StockCode**

# %%
df["StockCode"] = df["StockCode"].astype("str")
# Five digits + repeated letters
df[(df["StockCode"].str.match("^\\d{5}$") == False) & (df["StockCode"].str.match("^\\d{5}[a-zA-Z]+$") == False)]
# Out:
#         Invoice StockCode     Description  Quantity          InvoiceDate  \
# 89       489439      POST         POSTAGE         3  2009-12-01 09:28:00
# 126      489444      POST         POSTAGE         1  2009-12-01 09:55:00
# 173      489447      POST         POSTAGE         1  2009-12-01 10:10:00
# 625      489526      POST         POSTAGE         6  2009-12-01 11:50:00
# 735     C489535         D        Discount        -1  2009-12-01 12:11:00
# ...         ...       ...             ...       ...                  ...
# 524776   538147         M          Manual         1  2010-12-09 16:11:00
# 524887   538148       DOT  DOTCOM POSTAGE         1  2010-12-09 16:26:00
# 525000   538149       DOT  DOTCOM POSTAGE         1  2010-12-09 16:27:00
# 525126   538153       DOT  DOTCOM POSTAGE         1  2010-12-09 16:31:00
# 525147   538154       DOT  DOTCOM POSTAGE         1  2010-12-09 16:35:00
#
#                       Price          Customer ID         Country
# 89                    18.00             12682.00          France
# 126                  141.00             12636.00             USA
# 173                  130.00             12362.00         Belgium
# 625                   18.00             12533.00         Germany
# 735                    9.00             15299.00  United Kingdom
# ...                     ...                  ...             ...
# 524776                15.00             13090.00  United Kingdom
# 524887               547.32                  NaN  United Kingdom
# 525000               620.68                  NaN  United Kingdom
# 525126               822.94                  NaN  United Kingdom
# 525147                85.79                  NaN  United Kingdom
#
# [3098 rows x 8 columns]

# %%
df[
    (df["StockCode"].str.match("^\\d{5}$") == False)
    & (df["StockCode"].str.match("^\\d{5}[a-zA-Z]+$") == False)
]["StockCode"].unique()
# Out:
# array(['POST', 'D', 'DCGS0058', 'DCGS0068', 'DOT', 'M', 'DCGS0004',
#        'DCGS0076', 'C2', 'BANK CHARGES', 'DCGS0003', 'TEST001',
#        'gift_0001_80', 'DCGS0072', 'gift_0001_20', 'DCGS0044', 'TEST002',
#        'gift_0001_10', 'gift_0001_50', 'DCGS0066N', 'gift_0001_30',
#        'PADS', 'ADJUST', 'gift_0001_40', 'gift_0001_60', 'gift_0001_70',
#        'gift_0001_90', 'DCGSSGIRL', 'DCGS0006', 'DCGS0016', 'DCGS0027',
#        'DCGS0036', 'DCGS0039', 'DCGS0060', 'DCGS0056', 'DCGS0059', 'GIFT',
#        'DCGSLBOY', 'm', 'DCGS0053', 'DCGS0062', 'DCGS0037', 'DCGSSBOY',
#        'DCGSLGIRL', 'S', 'DCGS0069', 'DCGS0070', 'DCGS0075', 'B',
#        'DCGS0041', 'ADJUST2', '47503J ', 'C3', 'SP1002', 'AMAZONFEE'],
#       dtype=object)

# %%
df[df["StockCode"].str.contains("^DOT")]
# Out:
#        Invoice StockCode     Description  Quantity          InvoiceDate  \
# 2379    489597       DOT  DOTCOM POSTAGE         1  2009-12-01 14:28:00
# 2539    489600       DOT  DOTCOM POSTAGE         1  2009-12-01 14:43:00
# 2551    489601       DOT  DOTCOM POSTAGE         1  2009-12-01 14:44:00
# 2571    489602       DOT  DOTCOM POSTAGE         1  2009-12-01 14:45:00
# 2619    489603       DOT  DOTCOM POSTAGE         1  2009-12-01 14:46:00
# ...        ...       ...             ...       ...                  ...
# 524272  538071       DOT  DOTCOM POSTAGE         1  2010-12-09 14:09:00
# 524887  538148       DOT  DOTCOM POSTAGE         1  2010-12-09 16:26:00
# 525000  538149       DOT  DOTCOM POSTAGE         1  2010-12-09 16:27:00
# 525126  538153       DOT  DOTCOM POSTAGE         1  2010-12-09 16:31:00
# 525147  538154       DOT  DOTCOM POSTAGE         1  2010-12-09 16:35:00
#
#                       Price  Customer ID         Country
# 2379                 647.19          NaN  United Kingdom
# 2539                  55.96          NaN  United Kingdom
# 2551                  68.39          NaN  United Kingdom
# 2571                  59.35          NaN  United Kingdom
# 2619                  42.39          NaN  United Kingdom
# ...                     ...          ...             ...
# 524272               885.94          NaN  United Kingdom
# 524887               547.32          NaN  United Kingdom
# 525000               620.68          NaN  United Kingdom
# 525126               822.94          NaN  United Kingdom
# 525147                85.79          NaN  United Kingdom
#
# [736 rows x 8 columns]

# %%
# Define the list of unique non-standard StockCodes
non_standard_codes = df[
    (df["StockCode"].str.match("^\\d{5}$") == False)
    & (df["StockCode"].str.match("^\\d{5}[a-zA-Z]+$") == False)
]["StockCode"].unique()

# Loop through each non-standard StockCode
for code in non_standard_codes:
    # Filter the DataFrame for rows matching the current StockCode
    subset = df[df["StockCode"].str.contains(f"^{code}$", regex=True)]
    
    # Print basic information about this StockCode
    print(f"\nStockCode: {code}")
    print(f"Number of occurrences: {len(subset)}")
    print(f"Unique Descriptions: {subset['Description'].unique()}")
    print(f"Price Range: {subset['Price'].min()} to {subset['Price'].max()}")
    print(f"Customer ID Null Count: {subset['Customer ID'].isnull().sum()}")
    print(f"Sample rows:\n{subset.head().to_string(index=False)}\n")
# Out:
# StockCode: POST
# Number of occurrences: 865
# Unique Descriptions: ['POSTAGE' nan]
# Price Range: 0.0 to 850.0
# Customer ID Null Count: 43
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price          Customer ID        Country
#  489439      POST     POSTAGE         3 2009-12-01 09:28:00                18.00             12682.00         France
#  489444      POST     POSTAGE         1 2009-12-01 09:55:00               141.00             12636.00            USA
#  489447      POST     POSTAGE         1 2009-12-01 10:10:00               130.00             12362.00        Belgium
#  489526      POST     POSTAGE         6 2009-12-01 11:50:00                18.00             12533.00        Germany
# C489538      POST     POSTAGE        -1 2009-12-01 12:18:00                 9.58             15796.00 United Kingdom
#
#
# StockCode: D
# Number of occurrences: 100
# Unique Descriptions: ['Discount']
# Price Range: 0.01 to 1269.51
# Customer ID Null Count: 3
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price          Customer ID        Country
# C489535         D    Discount        -1 2009-12-01 12:11:00                 9.00             15299.00 United Kingdom
# C489535         D    Discount        -1 2009-12-01 12:11:00                19.00             15299.00 United Kingdom
# C491428         D    Discount        -1 2009-12-10 20:23:00                 9.10             15494.00 United Kingdom
# C491845         D    Discount        -1 2009-12-14 14:54:00                 1.59                  NaN United Kingdom
# C491962         D    Discount        -1 2009-12-14 16:38:00                 0.59             13206.00 United Kingdom
#
#
# StockCode: DCGS0058
# Number of occurrences: 31
# Unique Descriptions: ['MISO PRETTY  GUM' nan]
# Price Range: 0.0 to 0.95
# Customer ID Null Count: 31
# Sample rows:
# Invoice StockCode      Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  489597  DCGS0058 MISO PRETTY  GUM         1 2009-12-01 14:28:00                 0.83          NaN United Kingdom
#  490074  DCGS0058 MISO PRETTY  GUM         1 2009-12-03 14:39:00                 0.83          NaN United Kingdom
#  490745  DCGS0058 MISO PRETTY  GUM         1 2009-12-07 18:02:00                 0.83          NaN United Kingdom
#  491969  DCGS0058 MISO PRETTY  GUM         1 2009-12-14 17:57:00                 0.83          NaN United Kingdom
#  491970  DCGS0058 MISO PRETTY  GUM         1 2009-12-14 18:03:00                 0.83          NaN United Kingdom
#
#
# StockCode: DCGS0068
# Number of occurrences: 2
# Unique Descriptions: ['DOGS NIGHT COLLAR']
# Price Range: 8.47 to 8.65
# Customer ID Null Count: 2
# Sample rows:
# Invoice StockCode       Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  489597  DCGS0068 DOGS NIGHT COLLAR         1 2009-12-01 14:28:00                 8.65          NaN United Kingdom
#  494918  DCGS0068 DOGS NIGHT COLLAR         1 2010-01-19 17:49:00                 8.47          NaN United Kingdom
#
#
# StockCode: DOT
# Number of occurrences: 736
# Unique Descriptions: ['DOTCOM POSTAGE' nan]
# Price Range: 0.0 to 1081.7
# Customer ID Null Count: 736
# Sample rows:
# Invoice StockCode    Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  489597       DOT DOTCOM POSTAGE         1 2009-12-01 14:28:00               647.19          NaN United Kingdom
#  489600       DOT DOTCOM POSTAGE         1 2009-12-01 14:43:00                55.96          NaN United Kingdom
#  489601       DOT DOTCOM POSTAGE         1 2009-12-01 14:44:00                68.39          NaN United Kingdom
#  489602       DOT DOTCOM POSTAGE         1 2009-12-01 14:45:00                59.35          NaN United Kingdom
#  489603       DOT DOTCOM POSTAGE         1 2009-12-01 14:46:00                42.39          NaN United Kingdom
#
#
# StockCode: M
# Number of occurrences: 850
# Unique Descriptions: ['Manual']
# Price Range: 0.0 to 25111.09
# Customer ID Null Count: 200
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price          Customer ID        Country
#  489609         M      Manual         1 2009-12-01 14:50:00                 4.00                  NaN United Kingdom
# C489651         M      Manual        -1 2009-12-01 16:48:00                 5.10             17804.00 United Kingdom
# C489859         M      Manual        -1 2009-12-02 14:45:00                69.57                  NaN United Kingdom
# C490126         M      Manual        -1 2009-12-03 18:12:00                 5.95             15884.00 United Kingdom
# C490129         M      Manual        -1 2009-12-03 18:26:00              1998.49             15482.00 United Kingdom
#
#
# StockCode: DCGS0004
# Number of occurrences: 4
# Unique Descriptions: ['HAYNES CAMPER SHOULDER BAG' nan]
# Price Range: 0.0 to 17.35
# Customer ID Null Count: 4
# Sample rows:
# Invoice StockCode                Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  490074  DCGS0004 HAYNES CAMPER SHOULDER BAG         1 2009-12-03 14:39:00                17.35          NaN United Kingdom
#  498699  DCGS0004                        NaN        -2 2010-02-22 12:32:00                 0.00          NaN United Kingdom
#  504935  DCGS0004 HAYNES CAMPER SHOULDER BAG         1 2010-04-19 11:19:00                16.98          NaN United Kingdom
#  527789  DCGS0004 HAYNES CAMPER SHOULDER BAG         1 2010-10-19 11:10:00                16.98          NaN United Kingdom
#
#
# StockCode: DCGS0076
# Number of occurrences: 13
# Unique Descriptions: ['SUNJAR LED NIGHT NIGHT LIGHT']
# Price Range: 16.13 to 16.48
# Customer ID Null Count: 13
# Sample rows:
# Invoice StockCode                  Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  490074  DCGS0076 SUNJAR LED NIGHT NIGHT LIGHT         1 2009-12-03 14:39:00                16.48          NaN United Kingdom
#  490741  DCGS0076 SUNJAR LED NIGHT NIGHT LIGHT         1 2009-12-07 17:56:00                16.48          NaN United Kingdom
#  490745  DCGS0076 SUNJAR LED NIGHT NIGHT LIGHT         1 2009-12-07 18:02:00                16.48          NaN United Kingdom
#  491043  DCGS0076 SUNJAR LED NIGHT NIGHT LIGHT         1 2009-12-09 09:51:00                16.48          NaN United Kingdom
#  491969  DCGS0076 SUNJAR LED NIGHT NIGHT LIGHT         1 2009-12-14 17:57:00                16.48          NaN United Kingdom
#
#
# StockCode: C2
# Number of occurrences: 138
# Unique Descriptions: ['CARRIAGE' nan]
# Price Range: 0.0 to 110.0
# Customer ID Null Count: 13
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price          Customer ID        Country
#  490127        C2    CARRIAGE         1 2009-12-03 18:13:00                50.00             14156.00           EIRE
#  490541        C2    CARRIAGE         1 2009-12-07 09:25:00                50.00                  NaN           EIRE
#  490542        C2    CARRIAGE         1 2009-12-07 09:42:00                50.00             14911.00           EIRE
#  490998        C2    CARRIAGE         1 2009-12-08 17:24:00                50.00             16253.00 United Kingdom
#  491160        C2    CARRIAGE         1 2009-12-10 10:29:00                50.00             14911.00           EIRE
#
#
# StockCode: BANK CHARGES
# Number of occurrences: 65
# Unique Descriptions: [' Bank Charges' 'Bank Charges']
# Price Range: 0.96 to 18910.69
# Customer ID Null Count: 39
# Sample rows:
# Invoice    StockCode   Description  Quantity         InvoiceDate                Price          Customer ID        Country
# C490943 BANK CHARGES  Bank Charges        -1 2009-12-08 14:08:00                15.00             16703.00 United Kingdom
#  490948 BANK CHARGES  Bank Charges         1 2009-12-08 14:29:00                15.00             16805.00 United Kingdom
# C492206 BANK CHARGES  Bank Charges        -1 2009-12-15 16:32:00               848.43                  NaN United Kingdom
# C494438 BANK CHARGES  Bank Charges        -1 2010-01-14 12:15:00               767.99                  NaN United Kingdom
#  498269 BANK CHARGES  Bank Charges         1 2010-02-17 15:03:00                15.00             16928.00 United Kingdom
#
#
# StockCode: DCGS0003
# Number of occurrences: 9
# Unique Descriptions: ['BOXED GLASS ASHTRAY']
# Price Range: 2.51 to 2.57
# Customer ID Null Count: 9
# Sample rows:
# Invoice StockCode         Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  491041  DCGS0003 BOXED GLASS ASHTRAY         1 2009-12-09 09:42:00                 2.57          NaN United Kingdom
#  511858  DCGS0003 BOXED GLASS ASHTRAY         1 2010-06-11 10:05:00                 2.51          NaN United Kingdom
#  512437  DCGS0003 BOXED GLASS ASHTRAY         1 2010-06-15 16:17:00                 2.51          NaN United Kingdom
#  513099  DCGS0003 BOXED GLASS ASHTRAY         1 2010-06-21 15:13:00                 2.51          NaN United Kingdom
#  515287  DCGS0003 BOXED GLASS ASHTRAY         1 2010-07-09 14:58:00                 2.51          NaN United Kingdom
#
#
# StockCode: TEST001
# Number of occurrences: 15
# Unique Descriptions: ['This is a test product.']
# Price Range: 0.0 to 4.5
# Customer ID Null Count: 0
# Sample rows:
# Invoice StockCode             Description  Quantity         InvoiceDate                Price          Customer ID        Country
#  491725   TEST001 This is a test product.        10 2009-12-14 08:34:00                 4.50             12346.00 United Kingdom
#  491742   TEST001 This is a test product.         5 2009-12-14 11:00:00                 4.50             12346.00 United Kingdom
#  491744   TEST001 This is a test product.         5 2009-12-14 11:02:00                 4.50             12346.00 United Kingdom
#  492718   TEST001 This is a test product.         5 2009-12-18 10:47:00                 4.50             12346.00 United Kingdom
#  493410   TEST001 This is a test product.         5 2010-01-04 09:24:00                 4.50             12346.00 United Kingdom
#
#
# StockCode: gift_0001_80
# Number of occurrences: 4
# Unique Descriptions: [nan 'Dotcomgiftshop Gift Voucher £80.00']
# Price Range: 0.0 to 69.56
# Customer ID Null Count: 4
# Sample rows:
# Invoice    StockCode                        Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  491968 gift_0001_80                                NaN         2 2009-12-14 17:56:00                 0.00          NaN United Kingdom
#  491969 gift_0001_80 Dotcomgiftshop Gift Voucher £80.00         1 2009-12-14 17:57:00                69.56          NaN United Kingdom
# C494472 gift_0001_80 Dotcomgiftshop Gift Voucher £80.00        -1 2010-01-14 14:51:00                69.56          NaN United Kingdom
#  518488 gift_0001_80                                NaN        10 2010-08-09 12:29:00                 0.00          NaN United Kingdom
#
#
# StockCode: DCGS0072
# Number of occurrences: 3
# Unique Descriptions: ['CAT CAMOUFLAGUE COLLAR']
# Price Range: 5.17 to 5.17
# Customer ID Null Count: 3
# Sample rows:
# Invoice StockCode            Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  491969  DCGS0072 CAT CAMOUFLAGUE COLLAR         1 2009-12-14 17:57:00                 5.17          NaN United Kingdom
#  492303  DCGS0072 CAT CAMOUFLAGUE COLLAR         2 2009-12-16 11:57:00                 5.17          NaN United Kingdom
#  492783  DCGS0072 CAT CAMOUFLAGUE COLLAR         1 2009-12-18 17:15:00                 5.17          NaN United Kingdom
#
#
# StockCode: gift_0001_20
# Number of occurrences: 19
# Unique Descriptions: ['Dotcomgiftshop Gift Voucher £20.00' nan]
# Price Range: 0.0 to 17.39
# Customer ID Null Count: 19
# Sample rows:
# Invoice    StockCode                        Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  491971 gift_0001_20 Dotcomgiftshop Gift Voucher £20.00         2 2009-12-14 18:37:00                17.39          NaN United Kingdom
#  492782 gift_0001_20 Dotcomgiftshop Gift Voucher £20.00         1 2009-12-18 17:06:00                17.39          NaN United Kingdom
#  493404 gift_0001_20 Dotcomgiftshop Gift Voucher £20.00         1 2009-12-23 15:30:00                17.39          NaN United Kingdom
#  496247 gift_0001_20 Dotcomgiftshop Gift Voucher £20.00         1 2010-01-29 16:11:00                17.02          NaN United Kingdom
#  498443 gift_0001_20 Dotcomgiftshop Gift Voucher £20.00         1 2010-02-19 09:49:00                17.02          NaN United Kingdom
#
#
# StockCode: DCGS0044
# Number of occurrences: 1
# Unique Descriptions: ['HANDZ-OFF CAR FRESHENER']
# Price Range: 2.57 to 2.57
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode             Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  492226  DCGS0044 HANDZ-OFF CAR FRESHENER         1 2009-12-15 18:33:00                 2.57          NaN United Kingdom
#
#
# StockCode: TEST002
# Number of occurrences: 2
# Unique Descriptions: ['This is a test product.' nan]
# Price Range: 0.0 to 1.0
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode             Description  Quantity         InvoiceDate                Price          Customer ID        Country
#  492722   TEST002 This is a test product.         1 2009-12-18 10:55:00                 1.00             12346.00 United Kingdom
#  493294   TEST002                     NaN         1 2009-12-22 15:15:00                 0.00                  NaN United Kingdom
#
#
# StockCode: gift_0001_10
# Number of occurrences: 7
# Unique Descriptions: ['Dotcomgiftshop Gift Voucher £10.00' nan]
# Price Range: 0.0 to 8.69
# Customer ID Null Count: 7
# Sample rows:
# Invoice    StockCode                        Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  492782 gift_0001_10 Dotcomgiftshop Gift Voucher £10.00         1 2009-12-18 17:06:00                 8.69          NaN United Kingdom
#  501441 gift_0001_10 Dotcomgiftshop Gift Voucher £10.00         1 2010-03-16 13:44:00                 8.51          NaN United Kingdom
#  502486 gift_0001_10 Dotcomgiftshop Gift Voucher £10.00         1 2010-03-24 17:43:00                 8.51          NaN United Kingdom
#  510637 gift_0001_10 Dotcomgiftshop Gift Voucher £10.00         1 2010-06-02 11:54:00                 8.51          NaN United Kingdom
#  518496 gift_0001_10                                NaN        10 2010-08-09 12:31:00                 0.00          NaN United Kingdom
#
#
# StockCode: gift_0001_50
# Number of occurrences: 4
# Unique Descriptions: ['Dotcomgiftshop Gift Voucher £50.00' nan]
# Price Range: 0.0 to 43.48
# Customer ID Null Count: 4
# Sample rows:
# Invoice    StockCode                        Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  492783 gift_0001_50 Dotcomgiftshop Gift Voucher £50.00         1 2009-12-18 17:15:00                43.48          NaN United Kingdom
#  496249 gift_0001_50                                NaN         3 2010-01-29 16:17:00                 0.00          NaN United Kingdom
#  518491 gift_0001_50                                NaN        10 2010-08-09 12:29:00                 0.00          NaN United Kingdom
#  525755 gift_0001_50 Dotcomgiftshop Gift Voucher £50.00         1 2010-10-07 10:23:00                42.55          NaN United Kingdom
#
#
# StockCode: DCGS0066N
# Number of occurrences: 4
# Unique Descriptions: ['NAVY CUDDLES DOG HOODIE' nan]
# Price Range: 0.0 to 8.65
# Customer ID Null Count: 4
# Sample rows:
# Invoice StockCode             Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  493265 DCGS0066N NAVY CUDDLES DOG HOODIE         1 2009-12-22 15:05:00                 8.65          NaN United Kingdom
#  493268 DCGS0066N                     NaN         1 2009-12-22 15:07:00                 0.00          NaN United Kingdom
#  493269 DCGS0066N NAVY CUDDLES DOG HOODIE         1 2009-12-22 15:07:00                 8.65          NaN United Kingdom
#  493289 DCGS0066N                     NaN         1 2009-12-22 15:13:00                 0.00          NaN United Kingdom
#
#
# StockCode: gift_0001_30
# Number of occurrences: 21
# Unique Descriptions: ['Dotcomgiftshop Gift Voucher £30.00' nan]
# Price Range: 0.0 to 26.08
# Customer ID Null Count: 21
# Sample rows:
# Invoice    StockCode                        Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  493404 gift_0001_30 Dotcomgiftshop Gift Voucher £30.00         1 2009-12-23 15:30:00                26.08          NaN United Kingdom
#  494380 gift_0001_30                                NaN         5 2010-01-13 17:39:00                 0.00          NaN United Kingdom
#  494381 gift_0001_30 Dotcomgiftshop Gift Voucher £30.00         1 2010-01-13 17:44:00                25.53          NaN United Kingdom
#  495343 gift_0001_30 Dotcomgiftshop Gift Voucher £30.00         1 2010-01-22 18:05:00                25.53          NaN United Kingdom
#  502872 gift_0001_30 Dotcomgiftshop Gift Voucher £30.00         1 2010-03-29 09:59:00                25.53          NaN United Kingdom
#
#
# StockCode: PADS
# Number of occurrences: 15
# Unique Descriptions: ['PADS TO MATCH ALL CUSHIONS']
# Price Range: 0.001 to 36.6
# Customer ID Null Count: 0
# Sample rows:
# Invoice StockCode                Description  Quantity         InvoiceDate                Price          Customer ID        Country
#  494914      PADS PADS TO MATCH ALL CUSHIONS         1 2010-01-19 17:04:00                 0.00             16705.00 United Kingdom
#  496222      PADS PADS TO MATCH ALL CUSHIONS         1 2010-01-29 13:53:00                 0.00             13583.00 United Kingdom
#  496473      PADS PADS TO MATCH ALL CUSHIONS         1 2010-02-01 15:38:00                 0.00             17350.00 United Kingdom
#  496643      PADS PADS TO MATCH ALL CUSHIONS         1 2010-02-03 11:58:00                 0.00             13408.00 United Kingdom
#  497935      PADS PADS TO MATCH ALL CUSHIONS         1 2010-02-15 10:47:00                 0.00             13408.00 United Kingdom
#
#
# StockCode: ADJUST
# Number of occurrences: 67
# Unique Descriptions: ['Adjustment by john on 26/01/2010 16'
#  'Adjustment by john on 26/01/2010 17'
#  'Adjustment by Peter on 24/05/2010 1']
# Price Range: 4.57 to 5117.03
# Customer ID Null Count: 6
# Sample rows:
# Invoice StockCode                         Description  Quantity         InvoiceDate                Price          Customer ID        Country
#  495732    ADJUST Adjustment by john on 26/01/2010 16         1 2010-01-26 16:20:00                96.46                  NaN           EIRE
#  495733    ADJUST Adjustment by john on 26/01/2010 16         1 2010-01-26 16:21:00                68.34             14911.00           EIRE
#  495735    ADJUST Adjustment by john on 26/01/2010 16         1 2010-01-26 16:22:00               201.56             12745.00           EIRE
#  495734    ADJUST Adjustment by john on 26/01/2010 16         1 2010-01-26 16:22:00               205.82             14911.00           EIRE
# C495737    ADJUST Adjustment by john on 26/01/2010 16        -1 2010-01-26 16:23:00                10.50             16154.00 United Kingdom
#
#
# StockCode: gift_0001_40
# Number of occurrences: 4
# Unique Descriptions: [nan 'Dotcomgiftshop Gift Voucher £40.00']
# Price Range: 0.0 to 34.04
# Customer ID Null Count: 4
# Sample rows:
# Invoice    StockCode                        Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  496248 gift_0001_40                                NaN         3 2010-01-29 16:17:00                 0.00          NaN United Kingdom
#  518492 gift_0001_40                                NaN        10 2010-08-09 12:30:00                 0.00          NaN United Kingdom
#  518579 gift_0001_40 Dotcomgiftshop Gift Voucher £40.00         1 2010-08-10 12:08:00                31.35          NaN United Kingdom
#  528382 gift_0001_40 Dotcomgiftshop Gift Voucher £40.00         1 2010-10-21 18:01:00                34.04          NaN United Kingdom
#
#
# StockCode: gift_0001_60
# Number of occurrences: 2
# Unique Descriptions: [nan]
# Price Range: 0.0 to 0.0
# Customer ID Null Count: 2
# Sample rows:
# Invoice    StockCode Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  496250 gift_0001_60         NaN         3 2010-01-29 16:17:00                 0.00          NaN United Kingdom
#  518490 gift_0001_60         NaN        10 2010-08-09 12:29:00                 0.00          NaN United Kingdom
#
#
# StockCode: gift_0001_70
# Number of occurrences: 3
# Unique Descriptions: [nan 'Dotcomgiftshop Gift Voucher £70.00']
# Price Range: 0.0 to 59.57
# Customer ID Null Count: 3
# Sample rows:
# Invoice    StockCode                        Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  496251 gift_0001_70                                NaN         2 2010-01-29 16:17:00                 0.00          NaN United Kingdom
#  512168 gift_0001_70 Dotcomgiftshop Gift Voucher £70.00         1 2010-06-14 11:24:00                59.57          NaN United Kingdom
#  518489 gift_0001_70                                NaN        10 2010-08-09 12:29:00                 0.00          NaN United Kingdom
#
#
# StockCode: gift_0001_90
# Number of occurrences: 2
# Unique Descriptions: [nan]
# Price Range: 0.0 to 0.0
# Customer ID Null Count: 2
# Sample rows:
# Invoice    StockCode Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  496252 gift_0001_90         NaN         2 2010-01-29 16:18:00                 0.00          NaN United Kingdom
#  518487 gift_0001_90         NaN        10 2010-08-09 12:28:00                 0.00          NaN United Kingdom
#
#
# StockCode: DCGSSGIRL
# Number of occurrences: 12
# Unique Descriptions: [nan 'update' 'GIRLS PARTY BAG']
# Price Range: 0.0 to 3.36
# Customer ID Null Count: 12
# Sample rows:
# Invoice StockCode     Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  496722 DCGSSGIRL             NaN        -1 2010-02-03 14:04:00                 0.00          NaN United Kingdom
#  512738 DCGSSGIRL          update       100 2010-06-17 14:11:00                 0.00          NaN United Kingdom
#  513099 DCGSSGIRL GIRLS PARTY BAG         3 2010-06-21 15:13:00                 3.36          NaN United Kingdom
#  513200 DCGSSGIRL GIRLS PARTY BAG         6 2010-06-22 16:28:00                 3.36          NaN United Kingdom
#  513574 DCGSSGIRL GIRLS PARTY BAG         1 2010-06-25 15:13:00                 3.36          NaN United Kingdom
#
#
# StockCode: DCGS0006
# Number of occurrences: 1
# Unique Descriptions: [nan]
# Price Range: 0.0 to 0.0
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  496740  DCGS0006         NaN        -1 2010-02-03 14:28:00                 0.00          NaN United Kingdom
#
#
# StockCode: DCGS0016
# Number of occurrences: 1
# Unique Descriptions: [nan]
# Price Range: 0.0 to 0.0
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  496741  DCGS0016         NaN        -1 2010-02-03 14:29:00                 0.00          NaN United Kingdom
#
#
# StockCode: DCGS0027
# Number of occurrences: 1
# Unique Descriptions: [nan]
# Price Range: 0.0 to 0.0
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  496742  DCGS0027         NaN        -1 2010-02-03 14:29:00                 0.00          NaN United Kingdom
#
#
# StockCode: DCGS0036
# Number of occurrences: 1
# Unique Descriptions: [nan]
# Price Range: 0.0 to 0.0
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  496744  DCGS0036         NaN        -1 2010-02-03 14:35:00                 0.00          NaN United Kingdom
#
#
# StockCode: DCGS0039
# Number of occurrences: 1
# Unique Descriptions: [nan]
# Price Range: 0.0 to 0.0
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  496746  DCGS0039         NaN        -1 2010-02-03 14:36:00                 0.00          NaN United Kingdom
#
#
# StockCode: DCGS0060
# Number of occurrences: 1
# Unique Descriptions: [nan]
# Price Range: 0.0 to 0.0
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  496814  DCGS0060         NaN        -3 2010-02-04 09:46:00                 0.00          NaN United Kingdom
#
#
# StockCode: DCGS0056
# Number of occurrences: 1
# Unique Descriptions: [nan]
# Price Range: 0.0 to 0.0
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  496855  DCGS0056         NaN        -4 2010-02-04 11:46:00                 0.00          NaN United Kingdom
#
#
# StockCode: DCGS0059
# Number of occurrences: 1
# Unique Descriptions: [nan]
# Price Range: 0.0 to 0.0
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  496988  DCGS0059         NaN        -8 2010-02-05 11:21:00                 0.00          NaN United Kingdom
#
#
# StockCode: GIFT
# Number of occurrences: 1
# Unique Descriptions: [nan]
# Price Range: 0.0 to 0.0
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  497107      GIFT         NaN        -9 2010-02-05 15:18:00                 0.00          NaN United Kingdom
#
#
# StockCode: DCGSLBOY
# Number of occurrences: 1
# Unique Descriptions: [nan]
# Price Range: 0.0 to 0.0
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  497811  DCGSLBOY         NaN       -16 2010-02-12 14:45:00                 0.00          NaN United Kingdom
#
#
# StockCode: m
# Number of occurrences: 4
# Unique Descriptions: ['Manual']
# Price Range: 2.55 to 4.0
# Customer ID Null Count: 4
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  498492         m      Manual         1 2010-02-19 10:56:00                 2.55          NaN United Kingdom
#  498492         m      Manual         1 2010-02-19 10:56:00                 3.40          NaN United Kingdom
#  504396         m      Manual         1 2010-04-13 11:45:00                 4.00          NaN United Kingdom
#  511509         m      Manual         1 2010-06-08 15:26:00                 2.55          NaN United Kingdom
#
#
# StockCode: DCGS0053
# Number of occurrences: 1
# Unique Descriptions: [nan]
# Price Range: 0.0 to 0.0
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  498698  DCGS0053         NaN        -2 2010-02-22 12:29:00                 0.00          NaN United Kingdom
#
#
# StockCode: DCGS0062
# Number of occurrences: 2
# Unique Descriptions: [nan 'ROAD-RAGE CAR FRESHENER']
# Price Range: 0.0 to 2.51
# Customer ID Null Count: 2
# Sample rows:
# Invoice StockCode             Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  498700  DCGS0062                     NaN        -1 2010-02-22 12:34:00                 0.00          NaN United Kingdom
#  528952  DCGS0062 ROAD-RAGE CAR FRESHENER         1 2010-10-25 16:57:00                 2.51          NaN United Kingdom
#
#
# StockCode: DCGS0037
# Number of occurrences: 2
# Unique Descriptions: [nan 'KEY-RING CORKSCREW']
# Price Range: 0.0 to 12.72
# Customer ID Null Count: 2
# Sample rows:
# Invoice StockCode        Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  498701  DCGS0037                NaN        -1 2010-02-22 12:35:00                 0.00          NaN United Kingdom
#  512289  DCGS0037 KEY-RING CORKSCREW         1 2010-06-14 14:49:00                12.72          NaN United Kingdom
#
#
# StockCode: DCGSSBOY
# Number of occurrences: 12
# Unique Descriptions: [nan 'update' 'BOYS PARTY BAG']
# Price Range: 0.0 to 3.36
# Customer ID Null Count: 12
# Sample rows:
# Invoice StockCode    Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  499040  DCGSSBOY            NaN       -90 2010-02-24 13:16:00                 0.00          NaN United Kingdom
#  512737  DCGSSBOY         update       100 2010-06-17 14:10:00                 0.00          NaN United Kingdom
#  513099  DCGSSBOY BOYS PARTY BAG         5 2010-06-21 15:13:00                 3.36          NaN United Kingdom
#  513200  DCGSSBOY BOYS PARTY BAG         7 2010-06-22 16:28:00                 3.36          NaN United Kingdom
#  513574  DCGSSBOY BOYS PARTY BAG         3 2010-06-25 15:13:00                 3.36          NaN United Kingdom
#
#
# StockCode: DCGSLGIRL
# Number of occurrences: 1
# Unique Descriptions: [nan]
# Price Range: 0.0 to 0.0
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  499042 DCGSLGIRL         NaN       -57 2010-02-24 13:31:00                 0.00          NaN United Kingdom
#
#
# StockCode: S
# Number of occurrences: 41
# Unique Descriptions: ['SAMPLES']
# Price Range: 2.88 to 605.18
# Customer ID Null Count: 41
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price  Customer ID        Country
# C500305         S     SAMPLES        -1 2010-03-07 10:59:00                73.80          NaN United Kingdom
# C500309         S     SAMPLES        -1 2010-03-07 11:09:00                32.03          NaN United Kingdom
# C502083         S     SAMPLES        -1 2010-03-22 15:50:00               170.37          NaN United Kingdom
# C502088         S     SAMPLES        -1 2010-03-22 16:03:00               259.59          NaN United Kingdom
# C502438         S     SAMPLES        -1 2010-03-24 13:11:00               605.18          NaN United Kingdom
#
#
# StockCode: DCGS0069
# Number of occurrences: 4
# Unique Descriptions: ['OOH LA LA DOGS COLLAR']
# Price Range: 16.13 to 16.13
# Customer ID Null Count: 4
# Sample rows:
# Invoice StockCode           Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  501161  DCGS0069 OOH LA LA DOGS COLLAR         1 2010-03-15 09:28:00                16.13          NaN United Kingdom
#  503549  DCGS0069 OOH LA LA DOGS COLLAR         1 2010-04-01 15:04:00                16.13          NaN United Kingdom
#  503823  DCGS0069 OOH LA LA DOGS COLLAR         1 2010-04-07 14:59:00                16.13          NaN United Kingdom
#  528145  DCGS0069 OOH LA LA DOGS COLLAR         1 2010-10-20 15:56:00                16.13          NaN United Kingdom
#
#
# StockCode: DCGS0070
# Number of occurrences: 1
# Unique Descriptions: ['CAMOUFLAGE DOG COLLAR']
# Price Range: 12.72 to 12.72
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode           Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  503549  DCGS0070 CAMOUFLAGE DOG COLLAR         1 2010-04-01 15:04:00                12.72          NaN United Kingdom
#
#
# StockCode: DCGS0075
# Number of occurrences: 1
# Unique Descriptions: ['CAMOUFLAGUE DOG LEAD']
# Price Range: 12.72 to 12.72
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode          Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  503549  DCGS0075 CAMOUFLAGUE DOG LEAD         1 2010-04-01 15:04:00                12.72          NaN United Kingdom
#
#
# StockCode: B
# Number of occurrences: 3
# Unique Descriptions: ['Adjust bad debt']
# Price Range: -53594.36 to -38925.87
# Customer ID Null Count: 3
# Sample rows:
# Invoice StockCode     Description  Quantity         InvoiceDate                Price  Customer ID        Country
# A506401         B Adjust bad debt         1 2010-04-29 13:36:00            -53594.36          NaN United Kingdom
# A516228         B Adjust bad debt         1 2010-07-19 11:24:00            -44031.79          NaN United Kingdom
# A528059         B Adjust bad debt         1 2010-10-20 12:04:00            -38925.87          NaN United Kingdom
#
#
# StockCode: DCGS0041
# Number of occurrences: 1
# Unique Descriptions: ['HAYNES MINI-COOPER PLAYING CARDS']
# Price Range: 5.06 to 5.06
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode                      Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  511021  DCGS0041 HAYNES MINI-COOPER PLAYING CARDS         1 2010-06-04 16:13:00                 5.06          NaN United Kingdom
#
#
# StockCode: ADJUST2
# Number of occurrences: 3
# Unique Descriptions: ['Adjustment by Peter on Jun 25 2010 ']
# Price Range: 72.45 to 358.47
# Customer ID Null Count: 0
# Sample rows:
# Invoice StockCode                         Description  Quantity         InvoiceDate                Price          Customer ID        Country
#  513564   ADJUST2 Adjustment by Peter on Jun 25 2010          1 2010-06-25 14:15:00               300.13             17050.00 United Kingdom
#  513566   ADJUST2 Adjustment by Peter on Jun 25 2010          1 2010-06-25 14:15:00               358.47             17364.00 United Kingdom
#  513565   ADJUST2 Adjustment by Peter on Jun 25 2010          1 2010-06-25 14:15:00                72.45             16422.00 United Kingdom
#
#
# StockCode: 47503J
# Number of occurrences: 1
# Unique Descriptions: ['SET/3 FLORAL GARDEN TOOLS IN BAG']
# Price Range: 16.13 to 16.13
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode                      Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  514532   47503J  SET/3 FLORAL GARDEN TOOLS IN BAG         1 2010-07-05 10:07:00                16.13          NaN United Kingdom
#
#
# StockCode: C3
# Number of occurrences: 1
# Unique Descriptions: [nan]
# Price Range: 0.0 to 0.0
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price  Customer ID        Country
#  518785        C3         NaN     -4999 2010-08-11 16:55:00                 0.00          NaN United Kingdom
#
#
# StockCode: SP1002
# Number of occurrences: 3
# Unique Descriptions: ["KID'S CHALKBOARD/EASEL" nan]
# Price Range: 0.0 to 2.95
# Customer ID Null Count: 1
# Sample rows:
# Invoice StockCode            Description  Quantity         InvoiceDate                Price          Customer ID        Country
#  525772    SP1002 KID'S CHALKBOARD/EASEL         1 2010-10-07 11:12:00                 2.95             12748.00 United Kingdom
#  525837    SP1002 KID'S CHALKBOARD/EASEL         4 2010-10-07 12:23:00                 2.95             17841.00 United Kingdom
#  530135    SP1002                    NaN       -27 2010-11-01 15:33:00                 0.00                  NaN United Kingdom
#
#
# StockCode: AMAZONFEE
# Number of occurrences: 9
# Unique Descriptions: ['AMAZON FEE']
# Price Range: 1.0 to 13541.33
# Customer ID Null Count: 9
# Sample rows:
# Invoice StockCode Description  Quantity         InvoiceDate                Price  Customer ID        Country
# C531400 AMAZONFEE  AMAZON FEE        -1 2010-11-08 10:08:00              6706.71          NaN United Kingdom
#  531411 AMAZONFEE  AMAZON FEE         1 2010-11-08 10:11:00              6706.71          NaN United Kingdom
# C537600 AMAZONFEE  AMAZON FEE        -1 2010-12-07 12:41:00                 1.00          NaN United Kingdom
# C537630 AMAZONFEE  AMAZON FEE        -1 2010-12-07 15:04:00             13541.33          NaN United Kingdom
#  537632 AMAZONFEE  AMAZON FEE         1 2010-12-07 15:08:00             13541.33          NaN United Kingdom

# %% [markdown]
# StockCode is meant to follow the pattern [0-9]{5} but seems to have legit values for [0-9]{5}[a-zA-Z]+
#
# - Also contains other values:
#
# | Code            | Description                                                  | Action              |
# |-----------------|--------------------------------------------------------------|---------------------|
# | DCGS            | Looks valid, some quantities are negative though and customer ID is null | Exclude from clustering |
# | D               | Looks valid, represents discount values                     | Exclude from clustering |
# | DOT             | Looks valid, represents postage charges                     | Exclude from clustering |
# | M or m          | Looks valid, represents manual transactions                 | Exclude from clustering |
# | C2              | Carriage transaction - not sure what this means             | Exclude from clustering |
# | C3              | Not sure, only 1 transaction                                | Exclude             |
# | BANK CHARGES or B | Bank charges                                           | Exclude from clustering |
# | S               | Samples sent to customer                                    | Exclude from clustering |
# | TESTXXX         | Testing data, not valid                                     | Exclude             |
# | gift__XXX       | Purchases with gift cards, might be interesting for another analysis, but no customer data | Exclude |
# | PADS            | Looks like a legit stock code for padding                   | Include             |
# | SP1002          | Looks like a special request item, only 2 transactions, 3 look legit, 1 has 0 pricing | Exclude for now     |
# | AMAZONFEE       | Looks like fees for Amazon shipping or something            | Exclude for now     |
# | ADJUSTX         | Looks like manual account adjustments by admins             | Exclude for now     |

# %% [markdown]
# ### **Description**

# %%
missing_descriptions = df['Description'].isnull().sum()
print(f"Missing descriptions: {missing_descriptions}")
# Out:
# Missing descriptions: 2928

# %% [markdown]
# - This represents ~0.56% of the dataset, which is not a critical issue but should still be addressed.

# %%
unique_descriptions = df['Description'].nunique()
print(f"Unique product descriptions: {unique_descriptions}")
# Out:
# Unique product descriptions: 4681

# %% [markdown]
# - Diverse range of products, which aligns with the fact that the company sells unique giftware.

# %%
top_descriptions = df['Description'].value_counts().head(20)
print("Top 20 most common products:\n", top_descriptions)
# Out:
# Top 20 most common products:
#  Description
# WHITE HANGING HEART T-LIGHT HOLDER    3549
# REGENCY CAKESTAND 3 TIER              2212
# STRAWBERRY CERAMIC TRINKET BOX        1843
# PACK OF 72 RETRO SPOT CAKE CASES      1466
# ASSORTED COLOUR BIRD ORNAMENT         1457
# 60 TEATIME FAIRY CAKE CASES           1400
# HOME BUILDING BLOCK WORD              1386
# JUMBO BAG RED RETROSPOT               1310
# LUNCH BAG RED SPOTTY                  1274
# REX CASH+CARRY JUMBO SHOPPER          1232
# JUMBO STORAGE BAG SUKI                1220
# PACK OF 60 PINK PAISLEY CAKE CASES    1196
# WOODEN FRAME ANTIQUE WHITE            1190
# LUNCH BAG  BLACK SKULL.               1179
# BAKING SET 9 PIECE RETROSPOT          1176
# LUNCH BAG SUKI  DESIGN                1157
# HEART OF WICKER LARGE                 1151
# LOVE BUILDING BLOCK WORD              1142
# RED HANGING HEART T-LIGHT HOLDER      1129
# SWEETHEART CERAMIC TRINKET BOX        1096
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x=top_descriptions.values, y=top_descriptions.index, palette="viridis", hue=top_descriptions)
plt.title("Top 20 Most Frequent Products")
plt.xlabel("Frequency")
plt.ylabel("Product Description")
plt.tight_layout()
plt.show()

# %% [markdown]
# - The top 20 most common products are likely high-demand items.
# - Many of the top-selling products are decorative items, storage bags, lunch bags, cake-related accessories, and ornaments.

# %%
low_freq = df['Description'].value_counts()[df['Description'].value_counts() == 1]
print(f"Products purchased only once: {len(low_freq)}")
# Out:
# Products purchased only once: 263

# %% [markdown]
# - These might be niche products, one-time purchases, or potential data errors.

# %%
# Group by Customer ID to find top purchased items
customer_top_items = df.groupby(["Customer ID", "Description"])["Quantity"].sum().reset_index()
customer_top_items.sort_values(by="Quantity", ascending=False).head(20)
# Out:
#                 Customer ID                         Description  Quantity
# 69071              13902.00  BLACK AND WHITE PAISLEY FLOWER MUG     25164
# 162564             15838.00                 BROCADE RING PURSE      23760
# 207387             16754.00   WORLD WAR 2 GLIDERS ASSTD DESIGNS     20160
# 267992             17940.00            PACK OF 12 SUKI TISSUES      15800
# 267988             17940.00    PACK OF 12 PINK PAISLEY TISSUES      15008
# 267993             17940.00        PACK OF 12 WOODLAND TISSUES      14320
# 267990             17940.00      PACK OF 12 RED SPOTTY TISSUES      14008
# 69109              13902.00         SET/6 STRAWBERRY PAPER CUPS     12960
# 69112              13902.00         SET/6 WOODLAND PAPER PLATES     12960
# 69111              13902.00           SET/6 WOODLAND PAPER CUPS     12744
# 69110              13902.00       SET/6 STRAWBERRY PAPER PLATES     12480
# 69113              13902.00     SMALL FAIRY CAKE FRIDGE MAGNETS      9456
# 192525             16422.00                 BROCADE RING PURSE       9360
# 69092              13902.00                JAZZ HEARTS MEMO PAD      9312
# 186256             16308.00         SMALL CHINESE STYLE SCISSOR      8000
# 23823              12931.00       ASSORTED COLOUR BIRD ORNAMENT      7976
# 207374             16754.00              RED  HARMONICA IN BOX       7900
# 268121             17949.00                SMALL POPCORN HOLDER      7540
# 59661              13687.00        SET/6 FRUIT SALAD PAPER CUPS      7128
# 59660              13687.00     SET/6 FRUIT SALAD  PAPER PLATES      7008

# %% [markdown]
# - We see a bulk buyers pattern, this suggests certain customers may be wholesalers. The dominance of tissue packs and mugs also implies strong demand in those categories.

# %%
# Find the most purchased item per customer
top_items_per_customer = customer_top_items.loc[customer_top_items.groupby("Customer ID")["Quantity"].idxmax()]
top_items_per_customer
# Out:
#                 Customer ID                      Description  Quantity
# 27                 12346.00          This is a test product.        45
# 69                 12347.00          MINI PAINT SET VINTAGE         36
# 99                 12348.00      60 TEATIME FAIRY CAKE CASES        24
# 214                12349.00           WRAP PINK FAIRY CAKES         50
# 215                12351.00   BLUE SCANDINAVIAN PAISLEY WRAP        25
# ...                     ...                              ...       ...
# 281539             18283.00     HOMEMADE JAM SCENTED CANDLES        12
# 281667             18284.00                 RED SPOTS  WRAP         50
# 281681             18285.00         PAPER BUNTING WHITE LACE        80
# 281700             18286.00       DINOSAUR KEYRINGS ASSORTED        36
# 281822             18287.00  SET/6 PURPLE BUTTERFLY T-LIGHTS        96
#
# [4383 rows x 3 columns]

# %% [markdown]
# - This highlights that different customers focus on specific product categories.

# %%
# Count purchases per customer to identify one-time buyers
customer_purchases = df.groupby("Customer ID")["Invoice"].nunique().reset_index()
one_time_buyers = customer_purchases[customer_purchases["Invoice"] == 1]
# Count of one-time buyers
one_time_buyers_count = one_time_buyers.shape[0]
print(f"Number of one-time buyers: {one_time_buyers_count}")
# Out:
# Number of one-time buyers: 1267

# %%
# Find most common products among one-time buyers
one_time_purchases = df[df["Customer ID"].isin(one_time_buyers["Customer ID"])]
top_items_one_time_buyers = one_time_purchases["Description"].value_counts().head(20)
print("Top 10 most common products among one-time buyers:")
print(top_items_one_time_buyers)
# Out:
# Top 10 most common products among one-time buyers:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    163
# REX CASH+CARRY JUMBO SHOPPER          113
# REGENCY CAKESTAND 3 TIER               79
# PACK OF 6 BIRDY GIFT TAGS              75
# 60 TEATIME FAIRY CAKE CASES            73
# Manual                                 72
# VINTAGE SNAP CARDS                     69
# ASSORTED COLOUR BIRD ORNAMENT          69
# PAPER CHAIN KIT 50'S CHRISTMAS         67
# BAKING SET 9 PIECE RETROSPOT           67
# PACK OF 60 PINK PAISLEY CAKE CASES     67
# VINTAGE HEADS AND TAILS CARD GAME      66
# HEART OF WICKER LARGE                  64
# PLASTERS IN TIN CIRCUS PARADE          63
# FELTCRAFT 6 FLOWER FRIENDS             61
# HOME BUILDING BLOCK WORD               58
# PLASTERS IN TIN VINTAGE PAISLEY        57
# FELTCRAFT BUTTERFLY HEARTS             56
# RED HANGING HEART T-LIGHT HOLDER       56
# HANGING HEART ZINC T-LIGHT HOLDER      55
# Name: count, dtype: int64

# %%
# Data for the plot
products = [
    "WHITE HANGING HEART T-LIGHT HOLDER",
    "REX CASH+CARRY JUMBO SHOPPER",
    "REGENCY CAKESTAND 3 TIER",
    "PACK OF 6 BIRDY GIFT TAGS",
    "60 TEATIME FAIRY CAKE CASES"
]
purchase_counts = [163, 113, 79, 75, 73]

# Create the bar plot
# plt.figure(figsize=(10, 6))
plt.barh(products, purchase_counts, color="skyblue")
plt.xlabel("Number of Purchases")
plt.ylabel("Product Description")
plt.title("Top 5 Most Purchased Products by One-Time Buyers")
plt.gca().invert_yaxis()  # Invert y-axis for better readability
plt.grid(axis="x", alpha=0.7)
plt.show()

# %% [markdown]
# **Total One-Time Buyers**: 1,267 (≈ 29% of all customers)
# - **Common products purchased once**:
#   - WHITE HANGING HEART T-LIGHT HOLDER (163 times)
#   - REX CASH+CARRY JUMBO SHOPPER (113 times)
#   - REGENCY CAKESTAND 3 TIER (79 times)
#   - PACK OF 6 BIRDY GIFT TAGS (75 times)
#   - 60 TEATIME FAIRY CAKE CASES (73 times)
#
# The presence of decorative and gifting items in this list suggests many one-time buyers might be **seasonal shoppers** or **gift buyers**.

# %% [markdown]
# ### **Country**
# The majority of transactions come from the United Kingdom (485,852 rows, ~92%).

# %%
# Calculate revenue per country
df["Revenue"] = df["Quantity"] * df["Price"]
country_revenue = (
    df.groupby("Country")["Revenue"].sum().sort_values(ascending=False).head(10)
)

# Count transactions per country
country_transactions = df["Country"].value_counts().head(10)

# Count unique customers per country
country_customers = (
    df.groupby("Country")["Customer ID"].nunique().sort_values(ascending=False).head(10)
)

# Set up the figure
fig, axes = plt.subplots(3, 1, figsize=(12, 18))

# Revenue per country
sns.barplot(
    x=country_revenue.values,
    y=country_revenue.index,
    ax=axes[0],
    hue=country_revenue.index,
    palette="Blues_r",
    legend=False,
)
axes[0].set_title("Top 10 Countries by Revenue")
axes[0].set_xlabel("Total Revenue")
axes[0].set_ylabel("Country")

# Transactions per country
sns.barplot(
    x=country_transactions.values,
    y=country_transactions.index,
    ax=axes[1],
    hue=country_transactions.index,
    palette="Greens_r",
    legend=False,
)
axes[1].set_title("Top 10 Countries by Number of Transactions")
axes[1].set_xlabel("Number of Transactions")
axes[1].set_ylabel("Country")

# Unique customers per country
sns.barplot(
    x=country_customers.values,
    y=country_customers.index,
    ax=axes[2],
    hue=country_customers.index,
    palette="Reds_r",
    legend=False,
)
axes[2].set_title("Top 10 Countries by Unique Customers")
axes[2].set_xlabel("Number of Unique Customers")
axes[2].set_ylabel("Country")

plt.tight_layout()
plt.show()
